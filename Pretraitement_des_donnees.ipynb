# %%
import pandas as pd 
import numpy as np 
import os
import seaborn as sns  #pour la datavisu
import matplotlib.pyplot as plt 
# %matplotlib inline
sns.set_style('darkgrid')
import warnings as wr 
wr.filterwarnings("ignore")#pour ignorer les warnings
import seaborn 
import seaborn as sns
import matplotlib.pyplot as plt
#import plotly.graph_objs as go
#from plotly import tools
#import colorlover as cl
#pip install pandas-profiling[notebook]
#jupyter nbextension enable --py widgetsnbextension

# %%
Data = "OS/Desktop/cluster_file"

# %%
path= r"cluster_file"
directories = os.listdir(path)
for file in directories:
    print(file)
# Out:
# .ipynb_checkpoints
# olist_customers_dataset.csv
# olist_geolocation_dataset.csv
# olist_orders_dataset.csv
# olist_order_items_dataset.csv
# olist_order_payments_dataset.csv
# olist_order_reviews_dataset.csv
# olist_products_dataset.csv
# olist_sellers_dataset.csv
# Pretraitement_des_donnees.ipynb
# product_category_name_translation.csv

# %%
customers_df= pd.read_csv(r"cluster_file\olist_customers_dataset.csv")
geoloca_df= pd.read_csv(r"cluster_file\olist_geolocation_dataset.csv")
orders_payement_df= pd.read_csv(r"cluster_file\olist_order_payments_dataset.csv")
orders_items_df= pd.read_csv(r"cluster_file\olist_order_items_dataset.csv")

# %%
customers_df.info
geoloca_df.info
orders_payement_df.info
orders_items_df.info
# Out:
# <bound method DataFrame.info of                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
customers_df.head
geoloca_df.head
orders_payement_df.head
orders_items_df.head
# Out:
# <bound method NDFrame.head of                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
customers_df.dropna
geoloca_df.dropna
orders_payement_df.dropna
orders_items_df.dropna
# Out:
# <bound method DataFrame.dropna of                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
customers_df.dropna(axis=1)
geoloca_df.dropna(axis=1)
orders_payement_df.dropna(axis=1)
orders_items_df.dropna(axis=1)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
customers_df.fillna(0)
geoloca_df.fillna(0)
orders_payement_df.fillna(0)
orders_items_df.fillna(0)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_names = ['customers_df','geoloca_df', 'orders_payement_df', 'orders_items_df']
for df in df_names:
    print("Dataset {} has shape {}".format(df, eval(df).shape))
    print("In {} there are approximately {} null values".format(df, eval(df).isnull().sum().sum()))
# Out:
# Dataset customers_df has shape (99441, 5)
# In customers_df there are approximately 0 null values
# Dataset geoloca_df has shape (1000163, 5)
# In geoloca_df there are approximately 0 null values
# Dataset orders_payement_df has shape (103886, 5)
# In orders_payement_df there are approximately 0 null values
# Dataset orders_items_df has shape (112650, 7)
# In orders_items_df there are approximately 0 null values

# %%
orders_payement_df.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
customers_df.isnull()
geoloca_df.isnull()
orders_payement_df.isnull()
orders_items_df.isnull()
# Out:
#         order_id  order_item_id  product_id  seller_id  shipping_limit_date  \
# 0          False          False       False      False                False
# 1          False          False       False      False                False
# 2          False          False       False      False                False
# 3          False          False       False      False                False
# 4          False          False       False      False                False
# ...          ...            ...         ...        ...                  ...
# 112645     False          False       False      False                False
# 112646     False          False       False      False                False
# 112647     False          False       False      False                False
# 112648     False          False       False      False                False
# 112649     False          False       False      False                False
#
#         price  freight_value
# ...

# %%
#pip install <hcluster-0.2.0-cp27-none-win_amd64.whl>
#get_ipython().system('pip install pandas_profiling')
#import pandas_profiling
#customers_df.profile_report()
customers_df.duplicated()
geoloca_df.duplicated()
orders_items_df.duplicated()
orders_payement_df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103881    False
# 103882    False
# 103883    False
# 103884    False
# 103885    False
# Length: 103886, dtype: bool
